# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashzope/EDA_PracT/blob/main/EDA_PracT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import scipy
from scipy import stats
from collections import Counter
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import norm, t
from scipy.stats import expon
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import pylab
from pylab import legend
from pylab import plot,show,title ,xlabel,ylabel
import statsmodels
from statsmodels import stats
from statsmodels.stats import weightstats as ssw

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)



from numpy import random
from collections import Counter
from numpy.linalg import inv
from numpy.linalg import eig
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import pylab
from pylab import legend
from pylab import plot, show, title, xlabel, ylabel
import scipy
from scipy import stats
from scipy.stats import binom,poisson,norm,t,expon,f
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score

# %%
df = pd.read_csv("/content/drive/MyDrive/AAS_data/NetflixOriginals.csv",encoding="latin1")

# %%
df.describe()
# Out:
#           Runtime  IMDB Score
# count  584.000000  584.000000
# mean    93.577055    6.271747
# std     27.761683    0.979256
# min      4.000000    2.500000
# 25%     86.000000    5.700000
# 50%     97.000000    6.350000
# 75%    108.000000    7.000000
# max    209.000000    9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       584 non-null    object
#  1   Genre       584 non-null    object
#  2   Premiere    584 non-null    object
#  3   Runtime     584 non-null    int64
#  4   IMDB Score  584 non-null    float64
#  5   Language    584 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 27.5+ KB

# %%
df.isnull()
# Out:
#      Title  Genre  Premiere  Runtime  IMDB Score  Language
# 0    False  False     False    False       False     False
# 1    False  False     False    False       False     False
# 2    False  False     False    False       False     False
# 3    False  False     False    False       False     False
# 4    False  False     False    False       False     False
# ..     ...    ...       ...      ...         ...       ...
# 579  False  False     False    False       False     False
# 580  False  False     False    False       False     False
# 581  False  False     False    False       False     False
# 582  False  False     False    False       False     False
# 583  False  False     False    False       False     False
#
# [584 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 579    False
# 580    False
# 581    False
# 582    False
# 583    False
# Length: 584, dtype: bool

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Premiere', 'Runtime', 'IMDB Score', 'Language'], dtype='object')

# %%
#1 In which language were the long-running films created according to the dataset? Make visualizations.

# %%
df.head()
# Out:
#              Title                  Genre           Premiere  Runtime  \
# 0  Enter the Anime            Documentary     August 5, 2019       58
# 1      Dark Forces               Thriller    August 21, 2020       81
# 2          The App  Science fiction/Drama  December 26, 2019       79
# 3   The Open House        Horror thriller   January 19, 2018       94
# 4      Kaali Khuhi                Mystery   October 30, 2020       90
#
#    IMDB Score          Language
# 0         2.5  English/Japanese
# 1         2.6           Spanish
# 2         2.6           Italian
# 3         3.2           English
# 4         3.4             Hindi

# %%
np.mean(df.Runtime)
# Out:
# np.float64(93.57705479452055)

# %%
np.where (df.Runtime > 93.57)
# Out:
# (array([  3,   5,   6,   7,   9,  11,  12,  13,  16,  17,  18,  19,  21,
#          22,  23,  24,  26,  27,  28,  29,  37,  38,  42,  43,  44,  45,
#          46,  48,  49,  52,  54,  55,  57,  58,  60,  62,  63,  65,  67,
#          68,  69,  70,  71,  74,  75,  76,  77,  80,  81,  82,  83,  86,
#          87,  88,  89,  90,  91,  94,  97,  99, 100, 101, 102, 103, 104,
#         105, 106, 108, 109, 110, 112, 114, 115, 116, 118, 119, 120, 123,
#         125, 127, 128, 129, 130, 134, 135, 136, 137, 138, 141, 142, 143,
#         144, 146, 147, 149, 150, 155, 156, 157, 159, 161, 162, 164, 166,
#         168, 169, 170, 172, 174, 175, 176, 177, 178, 180, 181, 182, 183,
#         185, 186, 187, 190, 192, 193, 194, 195, 196, 198, 200, 203, 204,
#         205, 206, 207, 208, 210, 212, 213, 214, 215, 216, 217, 218, 219,
#         220, 222, 224, 225, 226, 229, 230, 231, 233, 234, 235, 236, 237,
#         241, 242, 246, 247, 248, 249, 251, 254, 255, 257, 258, 259, 260,
# ...

# %%
df1 = df.iloc[np.where (df.Runtime > 93.57)]

# %%
df1
# Out:
#                                      Title  \
# 3                           The Open House
# 5                                    Drive
# 6                        Leyla Everlasting
# 7          The Last Days of American Crime
# 9                       Sardar Ka Grandson
# ..                                     ...
# 573                                  Klaus
# 575  The Three Deaths of Marisela Escobedo
# 576                Cuba and the Cameraman
# 579  Taylor Swift: Reputation Stadium Tour
# 581                Springsteen on Broadway
#
#                                     Genre           Premiere  Runtime  \
# 3                         Horror thriller   January 19, 2018       94
# 5                                  Action   November 1, 2019      147
# 6                                  Comedy   December 4, 2020      112
# 7                     Heist film/Thriller       June 5, 2020      149
# 9                                  Comedy       May 18, 2021      139
# ...

# %%
np.mean(df1.Runtime)
# Out:
# np.float64(109.28089887640449)

# %%
np.max(df1.Runtime)    #movie with highest runtime
# Out:
# 209

# %%
np.percentile(df['Runtime'],75)
# Out:
# np.float64(108.0)

# %%
df1 = df.iloc [np.where(df['Runtime'] > np.percentile(df['Runtime'],75) )]

# %%
df1 # movies runtime greater then 75%ile
# Out:
#                                      Title                Genre  \
# 5                                    Drive               Action
# 6                        Leyla Everlasting               Comedy
# 7          The Last Days of American Crime  Heist film/Thriller
# 9                       Sardar Ka Grandson               Comedy
# 11                                The Call                Drama
# ..                                     ...                  ...
# 566                         The Ivory Game          Documentary
# 575  The Three Deaths of Marisela Escobedo          Documentary
# 576                Cuba and the Cameraman           Documentary
# 579  Taylor Swift: Reputation Stadium Tour         Concert Film
# 581                Springsteen on Broadway         One-man show
#
#               Premiere  Runtime  IMDB Score Language
# 5     November 1, 2019      147         3.5    Hindi
# 6     December 4, 2020      112         3.7  Turkish
# ...

# %%
df1   #In which language were the long-running films created according to the dataset?
# Out:
#                                      Title                Genre  \
# 5                                    Drive               Action
# 6                        Leyla Everlasting               Comedy
# 7          The Last Days of American Crime  Heist film/Thriller
# 9                       Sardar Ka Grandson               Comedy
# 11                                The Call                Drama
# ..                                     ...                  ...
# 566                         The Ivory Game          Documentary
# 575  The Three Deaths of Marisela Escobedo          Documentary
# 576                Cuba and the Cameraman           Documentary
# 579  Taylor Swift: Reputation Stadium Tour         Concert Film
# 581                Springsteen on Broadway         One-man show
#
#               Premiere  Runtime  IMDB Score Language
# 5     November 1, 2019      147         3.5    Hindi
# 6     December 4, 2020      112         3.7  Turkish
# ...

# %%
#In which language were the long-running films created according to the dataset? Make visualizations.
df1['Language'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Language'>

# %%
#2 Find and visualize the IMDB values of the movies shot in the 'Documentary' genre between January 2019 and June 2020.

# %%
df.head()
# Out:
#              Title                  Genre           Premiere  Runtime  \
# 0  Enter the Anime            Documentary     August 5, 2019       58
# 1      Dark Forces               Thriller    August 21, 2020       81
# 2          The App  Science fiction/Drama  December 26, 2019       79
# 3   The Open House        Horror thriller   January 19, 2018       94
# 4      Kaali Khuhi                Mystery   October 30, 2020       90
#
#    IMDB Score          Language
# 0         2.5  English/Japanese
# 1         2.6           Spanish
# 2         2.6           Italian
# 3         3.2           English
# 4         3.4             Hindi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       584 non-null    object
#  1   Genre       584 non-null    object
#  2   Premiere    584 non-null    object
#  3   Runtime     584 non-null    int64
#  4   IMDB Score  584 non-null    float64
#  5   Language    584 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 27.5+ KB

# %%
#Which genre has the highest IMDB rating among movies shot in English?

# %%
df.head()
# Out:
#              Title                  Genre           Premiere  Runtime  \
# 0  Enter the Anime            Documentary     August 5, 2019       58
# 1      Dark Forces               Thriller    August 21, 2020       81
# 2          The App  Science fiction/Drama  December 26, 2019       79
# 3   The Open House        Horror thriller   January 19, 2018       94
# 4      Kaali Khuhi                Mystery   October 30, 2020       90
#
#    IMDB Score          Language
# 0         2.5  English/Japanese
# 1         2.6           Spanish
# 2         2.6           Italian
# 3         3.2           English
# 4         3.4             Hindi

# %%
df3= np.where((df['Language'] == 'English') & (df['IMDB Score']) > np.percentile (df['IMDB Score'],75))

# %%
np.unique(df['Genre'])
# Out:
# array(['Action', 'Action comedy', 'Action thriller', 'Action-adventure',
#        'Action-thriller', 'Action/Comedy', 'Action/Science fiction',
#        'Adventure', 'Adventure-romance', 'Adventure/Comedy',
#        'Aftershow / Interview', 'Animated musical comedy', 'Animation',
#        'Animation / Comedy', 'Animation / Musicial',
#        'Animation / Science Fiction', 'Animation / Short',
#        'Animation/Christmas/Comedy/Adventure',
#        'Animation/Comedy/Adventure', 'Animation/Musical/Adventure',
#        'Animation/Superhero', 'Anime / Short', 'Anime/Fantasy',
#        'Anime/Science fiction', 'Anthology/Dark comedy',
#        'Biographical/Comedy', 'Biopic', 'Black comedy',
#        'Christian musical', 'Christmas comedy', 'Christmas musical',
#        'Christmas/Fantasy/Adventure/Comedy', 'Comedy', 'Comedy / Musical',
#        'Comedy horror', 'Comedy mystery', 'Comedy-drama',
#        'Comedy/Fantasy/Family', 'Comedy/Horror',
# ...

# %%
#How many categories does the Genre Column have and what are they? Visualize it.
df.value_counts(df['Genre']).head().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Genre'>

# %%
df['Genre'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='Genre'>

# %%
#Find the 3 most used languages in the movies in the data set.
df["Language"].value_counts().head(3)
# Out:
# Language
# English    401
# Hindi       33
# Spanish     31
# Name: count, dtype: int64

# %%
df["Language"].value_counts().head(3).plot(kind='bar')  #visualize
# Out:
# <Axes: xlabel='Language'>

# %%
#What is the average 'runtime' of movies shot in 'Hindi'?
df5 =df.iloc[np.where(df['Language'] == 'Hindi')]

# %%
df5
# Out:
#                                      Title                  Genre  \
# 4                              Kaali Khuhi                Mystery
# 5                                    Drive                 Action
# 9                       Sardar Ka Grandson                 Comedy
# 16                           Ghost Stories       Horror anthology
# 23                   The Girl on the Train               Thriller
# 45                      Mrs. Serial Killer               Thriller
# 87          Gunjan Saxena: The Kargil Girl                  Drama
# 97   Dolly Kitty and Those Twinkling Stars                  Drama
# 100                                 Guilty               Thriller
# 112                           House Arrest                 Comedy
# 147                       Ginny Weds Sunny        Romantic comedy
# 168                Choked: Paisa Bolta Hai                  Drama
# 169                           Class of '83                  Drama
# ...

# %%
df6 = np.mean(df5['Runtime'])

# %%
df6
# Out:
# np.float64(115.78787878787878)

# %%
#Top 10 Movies With IMDB Ratings

# %%
df7 = df.sort_values(by='IMDB Score',ascending=False).head(10)

# %%
df7
# Out:
#                                            Title         Genre  \
# 583     David Attenborough: A Life on Our Planet   Documentary
# 582    Emicida: AmarElo - It's All For Yesterday   Documentary
# 581                      Springsteen on Broadway  One-man show
# 579        Taylor Swift: Reputation Stadium Tour  Concert Film
# 578   Ben Platt: Live from Radio City Music Hall  Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom   Documentary
# 576                      Cuba and the Cameraman    Documentary
# 577                       Dancing with the Birds   Documentary
# 575        The Three Deaths of Marisela Escobedo   Documentary
# 574                                   Seaspiracy   Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# 583    October 4, 2020       83         9.0                   English
# 582   December 8, 2020       89         8.6                Portuguese
# ...

# %%
#What are the top 10 movies with the highest 'runtime'? Visualize it.
df.sort_values(by='Runtime'	,ascending = False).head(10)
# Out:
#                                Title                  Genre  \
# 561                     The Irishman            Crime drama
# 328                      Da 5 Bloods              War drama
# 581          Springsteen on Broadway           One-man show
# 247                         Citation                  Drama
# 284               The Forest of Love                  Drama
# 543                             Ludo  Anthology/Dark comedy
# 7    The Last Days of American Crime    Heist film/Thriller
# 509                   Raat Akeli Hai               Thriller
# 194                 Army of the Dead           Zombie/Heist
# 5                              Drive                 Action
#
#               Premiere  Runtime  IMDB Score  Language
# 561  November 27, 2019      209         7.8   English
# 328      June 12, 2020      155         6.5   English
# 581  December 16, 2018      153         8.5   English
# 247   November 6, 2020      151         6.2   English
# ...

# %%
df.sort_values(by='Runtime'	,ascending = False).head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
#Languages of movies lasting more than 2 hours.
df[df['Runtime']>120]['Language'].unique()
# Out:
# array(['Hindi', 'English', 'Japanese', 'Marathi', 'Spanish', 'Korean',
#        'Indonesian', 'Khmer/English/French', 'Portuguese',
#        'English/Korean', 'English/Akan'], dtype=object)

# %%
df.head()
# Out:
#              Title                  Genre           Premiere  Runtime  \
# 0  Enter the Anime            Documentary     August 5, 2019       58
# 1      Dark Forces               Thriller    August 21, 2020       81
# 2          The App  Science fiction/Drama  December 26, 2019       79
# 3   The Open House        Horror thriller   January 19, 2018       94
# 4      Kaali Khuhi                Mystery   October 30, 2020       90
#
#    IMDB Score          Language
# 0         2.5  English/Japanese
# 1         2.6           Spanish
# 2         2.6           Italian
# 3         3.2           English
# 4         3.4             Hindi

# %%
#Which genre has the highest IMDB rating among movies shot in English?
eng_movie = df['Language']=='English'
eng_movie
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 579     True
# 580    False
# 581     True
# 582    False
# 583     True
# Name: Language, Length: 584, dtype: bool

# %%
eng_movie = df.loc[eng_movie]

# %%
eng_movie
# Out:
#                                           Title                    Genre  \
# 3                                The Open House          Horror thriller
# 7               The Last Days of American Crime      Heist film/Thriller
# 8                                       Paradox  Musical/Western/Fantasy
# 10                         Searching for Sheela              Documentary
# 14                                        Mercy                 Thriller
# ..                                          ...                      ...
# 577                      Dancing with the Birds              Documentary
# 578  Ben Platt: Live from Radio City Music Hall             Concert Film
# 579       Taylor Swift: Reputation Stadium Tour             Concert Film
# 581                     Springsteen on Broadway             One-man show
# 583    David Attenborough: A Life on Our Planet              Documentary
#
#               Premiere  Runtime  IMDB Score Language
# ...

# %%
df=eng_movie.sort_values(by='IMDB Score',ascending=False).head(10)
df.Genre
# Out:
# 583                             Documentary
# 581                            One-man show
# 579                            Concert Film
# 578                            Concert Film
# 577                             Documentary
# 576                             Documentary
# 572                             Documentary
# 573    Animation/Christmas/Comedy/Adventure
# 574                             Documentary
# 571                             Documentary
# Name: Genre, dtype: object

# %%
#Top 10 Movies With Highest IMDB Ratings
df.sort_values(by='IMDB Score',ascending=False).head(10)
# Out:
#                                           Title  \
# 583    David Attenborough: A Life on Our Planet
# 581                     Springsteen on Broadway
# 579       Taylor Swift: Reputation Stadium Tour
# 578  Ben Platt: Live from Radio City Music Hall
# 577                      Dancing with the Birds
# 576                     Cuba and the Cameraman
# 572           Disclosure: Trans Lives on Screen
# 573                                       Klaus
# 574                                  Seaspiracy
# 571                                        13th
#
#                                     Genre           Premiere  Runtime  \
# 583                           Documentary    October 4, 2020       83
# 581                          One-man show  December 16, 2018      153
# 579                          Concert Film  December 31, 2018      125
# 578                          Concert Film       May 20, 2020       85
# 577                           Documentary   October 23, 2019       51
# ...

# %%
'''
head(10)
→ first 10 rows

nlargest()
→ top 10 values based on a column

'''
# Out:
# '\nhead(10)\n→ first 10 rows\n\nnlargest()\n→ top 10 values based on a column\n\n'

# %%
#Top 10 Movies With the Highest Runtime
df.sort_values(by='Runtime',ascending=False).head(10)
# Out:
#                                           Title  \
# 581                     Springsteen on Broadway
# 579       Taylor Swift: Reputation Stadium Tour
# 576                     Cuba and the Cameraman
# 572           Disclosure: Trans Lives on Screen
# 571                                        13th
# 573                                       Klaus
# 574                                  Seaspiracy
# 578  Ben Platt: Live from Radio City Music Hall
# 583    David Attenborough: A Life on Our Planet
# 577                      Dancing with the Birds
#
#                                     Genre           Premiere  Runtime  \
# 581                          One-man show  December 16, 2018      153
# 579                          Concert Film  December 31, 2018      125
# 576                           Documentary  November 24, 2017      114
# 572                           Documentary      June 19, 2020      107
# 571                           Documentary    October 7, 2016      100
# ...

# %%
#Which Language Movies Have the Lowest Average IMDB Rating?
df7=df.groupby('Language')['IMDB Score'].mean()

# %%
df7.sort_values(ascending=True).head(10).plot(kind = 'bar')
#visualization of least average rated movies in different language
# Out:
# <Axes: xlabel='Language'>

# %%
df7.sort_values(ascending=True).head(1)
# Out:
# Language
# Malay    4.2
# Name: IMDB Score, dtype: float64

# %%
#What is the Correlation Between IMDB Score and Runtime? Examine and Visualize

# %%
sns.scatterplot(x='Runtime',y='IMDB Score',data=df)
# Out:
# <Axes: xlabel='Runtime', ylabel='IMDB Score'>

# %%
corr_matrix = df[['Runtime','IMDB Score']].corr()
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
'''
 #here there is no correlation of runtime and IMDB score
 which means:
Longer Movies Are Not Better Movies
'''
# Out:
# '\n #here there is no correlation of runtime and IMDB score\n which means:\nLonger Movies Are Not Better Movies\n'

# %%
#Is There Any Outlier Data in the Dataset? Please Explain.
Q1 = df['Runtime'].quantile(0.25)
Q3 = df['Runtime'].quantile(0.75)
IQR = Q3 - Q1
Q1,Q3,IQR
# Out:
# (np.float64(86.0), np.float64(108.0), np.float64(22.0))

# %%
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR
lower_bound,upper_bound
# Out:
# (np.float64(53.0), np.float64(141.0))

# %%
runtime_outlier = df[(df['Runtime'] < lower_bound) | (df['Runtime'] > upper_bound)]
runtime_outlier
# Out:
#                                Title                Genre           Premiere  \
# 5                              Drive               Action   November 1, 2019
# 7    The Last Days of American Crime  Heist film/Thriller       June 5, 2020
# 15                    After the Raid          Documentary  December 19, 2019
# 16                     Ghost Stories     Horror anthology    January 1, 2020
# 30                       After Maria          Documentary       May 24, 2019
# ..                               ...                  ...                ...
# 552                            Anima      Musical / Short      June 27, 2019
# 560   If Anything Happens I Love You    Animation / Short  November 20, 2020
# 561                     The Irishman          Crime drama  November 27, 2019
# 577           Dancing with the Birds          Documentary   October 23, 2019
# 581          Springsteen on Broadway         One-man show  December 16, 2018
#
#      Runtime  IMDB Score         Language
# ...

# %%
sns.boxplot(x=df['Runtime'])
# Out:
# <Axes: xlabel='Runtime'>

# %%
Q1 = df['IMDB Score'].quantile(0.25)

Q3 = df['IMDB Score'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5*IQR

upper_bound = Q3 + 1.5*IQR

imdb_outliers = df[
    (df['IMDB Score'] < lower_bound) |
    (df['IMDB Score'] > upper_bound)
]

imdb_outliers
# Out:
#                                         Title                  Genre  \
# 0                             Enter the Anime            Documentary
# 1                                 Dark Forces               Thriller
# 2                                     The App  Science fiction/Drama
# 3                              The Open House        Horror thriller
# 4                                 Kaali Khuhi                Mystery
# 5                                       Drive                 Action
# 6                           Leyla Everlasting                 Comedy
# 7             The Last Days of American Crime    Heist film/Thriller
# 583  David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score          Language
# 0       August 5, 2019       58         2.5  English/Japanese
# 1      August 21, 2020       81         2.6           Spanish
# 2    December 26, 2019       79         2.6           Italian
# ...

# %%
sns.boxplot(x=df['IMDB Score'])
# Out:
# <Axes: xlabel='IMDB Score'>
