# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashzope/EDA_PracT/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
from numpy import random
from collections import Counter
from numpy.linalg import inv
from numpy.linalg import eig
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import pylab
from pylab import legend
from pylab import plot, show, title, xlabel, ylabel
import scipy
from scipy import stats
from scipy.stats import binom,poisson,norm,t,expon,f
from sklearn.model_selection import train_test_split
import statsmodels
from statsmodels import stats
from statsmodels.stats import weightstats as ssw
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import statsmodels.stats
from statsmodels.stats.proportion import proportions_ztest
from scipy.stats import chisquare
from scipy.stats import chi2_contingency
from statsmodels.stats import rates
from statsmodels.stats.rates import test_poisson
from statsmodels.stats.rates import test_poisson_2indep
from scipy.stats import chi2
from scipy.stats import f
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
# from category_encoders import BinaryEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import log_loss
from statsmodels.discrete.discrete_model import MNLogit
from statsmodels.miscmodels.ordinal_model import OrderedModel
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import statsmodels.formula.api as smf
from statsmodels.discrete.discrete_model import Poisson as psn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.api import SimpleExpSmoothing
from statsmodels.tsa.api import Holt
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
import tensorflow
from tensorflow.keras.models import Sequential  # helps with the forward and backward propagation
from tensorflow.keras.layers import Dense  # this is for the hidden, input and output layers
from tensorflow.keras.layers import ReLU    # activation function
from tensorflow.keras.layers import Dropout   # switching off the neurons
import os
print(os.getcwd())
os.chdir('/content/drive/MyDrive/AAS_data')
os.getcwd()
# Out:
# /content/drive/MyDrive/AAS_data
# '/content/drive/MyDrive/AAS_data'

# %%
df1 = pd.read_csv("/content/drive/MyDrive/AAS_data/sm/merged_analysis.csv")
df2 = pd.read_csv("/content/drive/MyDrive/AAS_data/sm/ticker_statistics.csv")
df3= pd.read_csv("/content/drive/MyDrive/AAS_data/sm/balance_sheet.csv")
df4= pd.read_csv("/content/drive/MyDrive/AAS_data/sm/financial_ratios.csv")
df5= pd.read_csv("/content/drive/MyDrive/AAS_data/sm/quarterly_results.csv")
df6= pd.read_csv("/content/drive/MyDrive/AAS_data/sm/cash_flow.csv")
df7= pd.read_csv("/content/drive/MyDrive/AAS_data/sm/historical_data.csv")
df8= pd.read_csv("/content/drive/MyDrive/AAS_data/sm/company_overview.csv")
df9= pd.read_csv("/content/drive/MyDrive/AAS_data/sm/nse_tickers.csv")

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
print(df6.shape)
print(df7.shape)
print(df8.shape)
print(df9.shape)
# Out:
# (1414, 56)
# (1472, 14)
# (5482, 55)
# (9057, 41)
# (8002, 39)
# (84, 51)
# (1508662, 8)
# (1472, 25)
# (1472, 7)

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
print(df4.columns)
print(df5.columns)
print(df6.columns)
print(df7.columns)
print(df8.columns)
print(df9.columns)
# Out:
# Index(['symbol', 'trading_days', 'avg_price', 'min_price', 'max_price',
#        'avg_volume', 'total_volume', 'avg_daily_return', 'volatility',
#        'max_daily_gain', 'max_daily_loss', 'annualized_return_pct',
#        'annualized_volatility_pct', 'total_return_pct', 'date',
#        'gross_margin_pct', 'operating_margin_pct', 'net_profit_margin_pct',
#        'ebitda_margin_pct', 'roe_pct', 'roa_pct', 'roce_pct', 'current_ratio',
#        'quick_ratio', 'cash_ratio', 'debt_to_equity', 'debt_to_assets',
#        'interest_coverage', 'equity_multiplier', 'asset_turnover',
#        'inventory_turnover', 'receivables_turnover', 'payables_turnover',
#        'days_inventory', 'days_receivables', 'days_payables',
#        'cash_conversion_cycle', 'operating_cf_to_revenue', 'fcf_to_revenue',
#        'capex_to_revenue', 'fcf_to_net_income', 'eps_basic', 'eps_diluted',
#        'pe_ratio', 'forward_pe', 'pb_ratio', 'ev_ebitda', 'ev_revenue',
# ...

# %%
print(df1.isnull().sum())
print("------------------------------------")
print(df2.isnull().sum())
print("------------------------------------")
print(df3.isnull().sum())
print("------------------------------------")
print(df4.isnull().sum())
print("------------------------------------")
print(df5.isnull().sum())
print("------------------------------------")
print(df6.isnull().sum())
print("------------------------------------")
print(df7.isnull().sum())
print("------------------------------------")
print(df8.isnull().sum())
print("------------------------------------")
print(df9.isnull().sum())
# Out:
# symbol                          0
# trading_days                    0
# avg_price                       0
# min_price                       0
# max_price                       0
# avg_volume                      0
# total_volume                    0
# avg_daily_return                0
# volatility                      0
# max_daily_gain                  0
# max_daily_loss                  0
# annualized_return_pct           0
# annualized_volatility_pct       0
# total_return_pct                0
# date                            0
# gross_margin_pct               31
# operating_margin_pct           15
# net_profit_margin_pct           5
# ebitda_margin_pct              15
# roe_pct                        11
# roa_pct                        10
# roce_pct                       21
# current_ratio                  23
# quick_ratio                   184
# cash_ratio                     23
# debt_to_equity                 46
# debt_to_assets                 45
# ...

# %%
df8['sector'].value_counts()    #sector wise companies present in the dataset
# Out:
# sector
# Industrials               323
# Consumer Cyclical         302
# Basic Materials           273
# Technology                119
# Financial Services        110
# Consumer Defensive        103
# Healthcare                 95
# Real Estate                65
# Communication Services     46
# Energy                     19
# Utilities                  14
# Name: count, dtype: int64

# %%
(df8['sector'].value_counts()).plot(kind='bar')
# Out:
# <Axes: xlabel='sector'>

# %%
df8[['company_name','sector']]
# Out:
#                          company_name              sector
# 0                  20 Microns Limited     Basic Materials
# 1                 3i Infotech Limited          Technology
# 2              5paisa Capital Limited  Financial Services
# 3       63 moons technologies limited          Technology
# 4       A2Z Infra Engineering Limited         Industrials
# ...                               ...                 ...
# 1467         ZIM Laboratories Limited          Healthcare
# 1468  Zodiac Clothing Company Limited   Consumer Cyclical
# 1469         Zota Health Care Limited          Healthcare
# 1470     Zuari Agro Chemicals Limited     Basic Materials
# 1471         Zuari Industries Limited         Industrials
#
# [1472 rows x 2 columns]

# %%
df8[df8['sector']=='Technology']
# Out:
#           symbol                           company_name      sector  \
# 1      3IINFOLTD                    3i Infotech Limited  Technology
# 3        63MOONS          63 moons technologies limited  Technology
# 5        AAATECH               AAA Technologies Limited  Technology
# 16       ACCELYA        Accelya Solutions India Limited  Technology
# 21          ADSL        Allied Digital Services Limited  Technology
# ...          ...                                    ...         ...
# 1439  WEBELSOLAR           Websol Energy System Limited  Technology
# 1455   XCHANGING            Xchanging Solutions Limited  Technology
# 1456     XELPMOC        Xelpmoc Design and Tech Limited  Technology
# 1458    XTGLOBAL              XTGlobal Infotech Limited  Technology
# 1463      ZAGGLE  Zaggle Prepaid Ocean Services Limited  Technology
#
#                              industry  market_cap_crore  52w_high  52w_low  \
# ...

# %%
df8[df8['sector'] == 'Financial Services']
# Out:
#           symbol                                 company_name  \
# 2         5PAISA                       5paisa Capital Limited
# 32          AFIL                    AKME FINTRADE (INDIA) LTD
# 33          AFSL             Abans Financial Services Limited
# 51     ALGOQUANT                    Algoquant Fintech Limited
# 57       ALMONDZ            Almondz Global Securities Limited
# ...          ...                                          ...
# 1379   UYFINCORP                        U. Y. Fincorp Limited
# 1400         VHL                    Vardhman Holdings Limited
# 1423  VLSFINANCE                          VLS Finance Limited
# 1438      WEALTH      Wealth First Portfolio Managers Limited
# 1443      WELINV  Welspun Investments and Commercials Limited
#
#                   sector         industry  market_cap_crore  52w_high  \
# 2     Financial Services  Capital Markets           1645.46    432.50
# 32    Financial Services  Credit Services            611.21     11.10
# ...

# %%
df8[df8['sector']=='Healthcare']
# Out:
#           symbol                                      company_name  \
# 6     AAREYDRUGS             Aarey Drugs & Pharmaceuticals Limited
# 9     AARTIDRUGS                               Aarti Drugs Limited
# 10    AARTIPHARM                          Aarti Pharmalabs Limited
# 37          AHCL                          ANLON HEALTHCARE LIMITED
# 47         AKUMS                          AKUMS DRUGS AND PHARMA L
# ...          ...                                               ...
# 1436     WANBURY                                   Wanbury Limited
# 1448     WINDLAS                           Windlas Biotech Limited
# 1460    YATHARTH  Yatharth Hospital & Trauma Care Services Limited
# 1467      ZIMLAB                          ZIM Laboratories Limited
# 1469        ZOTA                          Zota Health Care Limited
#
#           sector                                  industry  market_cap_crore  \
# 6     Healthcare  Drug Manufacturers - Specialty & Generic            257.32
# ...

# %%
(df8.sort_values('market_cap_crore',ascending=False)
[['company_name','sector','market_cap_crore']].head(20))
# Out:
#                                   company_name                  sector  \
# 758                    Vedant Fashions Limited       Consumer Cyclical
# 631                  Jubilant Ingrevia Limited         Basic Materials
# 998                  QUALITY POWER ELEC EQUP L             Industrials
# 846                                NCC Limited             Industrials
# 263                             Cyient Limited             Industrials
# 994                           PVR INOX Limited  Communication Services
# 423        Genus Power Infrastructures Limited             Industrials
# 1255                     SUDEEP PHARMA LIMITED              Healthcare
# 945            Pearl Global Industries Limited       Consumer Cyclical
# 146             Banco Products (India) Limited       Consumer Cyclical
# 1038              Religare Enterprises Limited      Financial Services
# 1397                    Vesuvius India Limited             Industrials
# ...

# %%
df10 = df8.sort_values(['sector','market_cap_crore'],ascending=[False,False]).groupby('sector').head(1).head(5)

# %%
symbols = df10['symbol'].tolist()

# %%
symbols
# Out:
# ['INOXGREEN', 'UTLSOLAR', 'WEWORK', 'QPOWER', 'SUDEEPPHRM']

# %%
company = df8[df8['symbol'].isin(symbols)]

# %%
company.head()
# Out:
#           symbol                        company_name       sector  \
# 576    INOXGREEN  Inox Green Energy Services Limited    Utilities
# 998       QPOWER           QUALITY POWER ELEC EQUP L  Industrials
# 1255  SUDEEPPHRM               SUDEEP PHARMA LIMITED   Healthcare
# 1377    UTLSOLAR            FUJIYAMA POWER SYSTEMS L   Technology
# 1446      WEWORK           WEWORK INDIA MANAGEMENT L  Real Estate
#
#                                       industry  market_cap_crore  52w_high  \
# 576                      Utilities - Renewable           8025.02     279.0
# 998               Electrical Equipment & Parts           9911.30    1441.0
# 1255  Drug Manufacturers - Specialty & Generic           9611.36     882.4
# 1377                                     Solar           9437.23     365.0
# 1446                      Real Estate Services           8914.82     678.9
#
#       52w_low  current_price  avg_volume  beta  dividend_yield    pe_ratio  \
# ...

# %%
historical = df7[df7['symbol'].isin(symbols)]

# %%
historical.head()
# Out:
#            symbol        date       open       high        low      close  \
# 587161  INOXGREEN  2022-11-23  60.000000  64.000000  58.349998  59.099998
# 587162  INOXGREEN  2022-11-24  59.700001  63.799999  59.150002  61.450001
# 587163  INOXGREEN  2022-11-25  61.900002  62.799999  61.000000  62.299999
# 587164  INOXGREEN  2022-11-28  62.299999  62.950001  60.400002  61.349998
# 587165  INOXGREEN  2022-11-29  60.750000  62.400002  60.049999  60.450001
#
#         adj_close      volume
# 587161  59.099998  40023843.0
# 587162  61.450001  11843525.0
# 587163  62.299999   3229538.0
# 587164  61.349998   4647348.0
# 587165  60.450001   2032907.0

# %%
balance = df3[df3['symbol'].isin(symbols)]
balance.head()
# Out:
#          symbol        date  total_assets  current_assets  \
# 2158  INOXGREEN  2026-03-31  2.112860e+10    1.040940e+10
# 2159  INOXGREEN  2025-09-30  2.465560e+10    1.032140e+10
# 2160  INOXGREEN  2025-03-31  2.486899e+10    1.005387e+10
# 2161  INOXGREEN  2024-09-30  2.641300e+10    1.148240e+10
# 3716     QPOWER  2026-03-31  1.111962e+10    7.321400e+09
#
#       cash_and_equivalents  cash_and_st_investments  short_term_investments  \
# 2158          8.689000e+08             6.255400e+09            5.386500e+09
# 2159          1.805000e+08             3.842700e+09            3.662200e+09
# 2160          6.310500e+07             1.871202e+09            1.808097e+09
# 2161          1.145000e+08             3.152500e+09            3.038000e+09
# 3716          1.837800e+09             2.875700e+09            1.037900e+09
#
#       receivables  accounts_receivable  other_receivables     inventory  \
# 2158          NaN         1.661800e+09       1.156300e+09  1.016200e+09
# ...

# %%
cashflow = df6[df6['symbol'].isin(symbols)]
cashflow.head()
# Out:
#         symbol        date  operating_cash_flow  cfo_continuing  \
# 69  SUDEEPPHRM  2025-06-30          -54840000.0             NaN
# 72    UTLSOLAR  2025-06-30          -45510000.0             NaN
#
#     ni_continuing  depreciation_amortization  depreciation_depletion  \
# 69    440720000.0                 32520000.0                     NaN
# 72    899340000.0                 70110000.0                     NaN
#
#     deferred_tax  deferred_income_tax  stock_based_compensation  \
# 69           NaN                  NaN                       NaN
# 72           NaN                  NaN                 -200000.0
#
#     change_working_capital  change_receivables  change_inventory  \
# 69            -406660000.0         227130000.0      -218080000.0
# 72            -961340000.0         -92370000.0      -959710000.0
#
#     change_payables  change_payable  change_other_working_capital  \
# 69              NaN    -117430000.0                           NaN
# ...

# %%
ratios = df4[df4['symbol'].isin(symbols)]
ratios.head(5)
# Out:
#          symbol        date  gross_margin_pct  operating_margin_pct  \
# 3568  INOXGREEN  2024-09-30               NaN                   NaN
# 3569  INOXGREEN  2025-03-31             39.68                 -5.00
# 3570  INOXGREEN  2025-06-30             49.95                 -8.83
# 3571  INOXGREEN  2025-09-30             38.03                 -1.75
# 3572  INOXGREEN  2025-12-31             53.67                 14.73
#
#       net_profit_margin_pct  ebitda_margin_pct  roe_pct  roa_pct  roce_pct  \
# 3568                    NaN                NaN      NaN      NaN       NaN
# 3569                   8.61              27.56     1.13     0.89      3.20
# 3570                  39.20              84.88      NaN      NaN       NaN
# 3571                  32.49              60.78     5.53     4.53      7.49
# 3572                  30.19              64.38      NaN      NaN       NaN
#
#       current_ratio  quick_ratio  cash_ratio  debt_to_equity  debt_to_assets  \
# ...

# %%
statistics = df2[df2['symbol'].isin(symbols)]
statistics.head()
# Out:
#           symbol  trading_days   avg_price   min_price    max_price  \
# 576    INOXGREEN           887  133.076280   38.400002   279.000000
# 998       QPOWER           329  777.197665  267.529085  1441.000000
# 1255  SUDEEPPHRM           142  656.396479  524.049988   882.400024
# 1377    UTLSOLAR           148  235.864459  172.000000   365.000000
# 1446      WEWORK           173  569.879768  420.000000   678.900024
#
#         avg_volume  total_volume  avg_daily_return  volatility  \
# 576   2.429813e+06  2.155244e+09          0.001928    0.033592
# 998   1.046656e+06  3.443497e+08          0.004432    0.039924
# 1255  6.614058e+05  9.391962e+07          0.001082    0.028969
# 1377  6.942372e+05  1.027471e+08          0.003057    0.028812
# 1446  3.208496e+05  5.550699e+07          0.000435    0.025071
#
#       max_daily_gain  max_daily_loss  annualized_return_pct  \
# 576         0.199933       -0.102327              48.590112
# ...

# %%
print(company.shape)
print(historical.shape)
print(balance.shape)
print(cashflow.shape)
print(ratios.shape)
print(statistics.shape)
# Out:
# (5, 25)
# (1679, 8)
# (16, 55)
# (2, 51)
# (26, 41)
# (5, 14)

# %%
(df1.head())
# Out:
#       symbol  trading_days   avg_price   min_price    max_price  \
# 0  20MICRONS          1237  148.219271   47.637056   346.435425
# 1  3IINFOLTD          1237   40.304158   12.680000   119.300003
# 2     5PAISA          1237  401.122692  245.500000   758.450012
# 3    63MOONS          1238  420.298080   84.241981  1128.542768
# 4    AAATECH          1236   75.068344   27.996203   157.748785
#
#       avg_volume  total_volume  avg_daily_return  volatility  max_daily_gain  \
# 0  245003.299919  3.030691e+08          0.001500    0.032850        0.200000
# 1  978520.287793  1.210430e+09         -0.000698    0.034822        0.199929
# 2   94904.080032  1.173963e+08          0.000192    0.026114        0.199896
# 3  241762.878029  2.993024e+08          0.002204    0.034371        0.199881
# 4   57645.259709  7.124954e+07          0.001191    0.033294        0.200000
#
#    max_daily_loss  annualized_return_pct  annualized_volatility_pct  \
# ...

# %%
(df2.head())
# Out:
#       symbol  trading_days   avg_price   min_price    max_price  \
# 0  20MICRONS          1237  148.219271   47.637056   346.435425
# 1  3IINFOLTD          1237   40.304158   12.680000   119.300003
# 2     5PAISA          1237  401.122692  245.500000   758.450012
# 3    63MOONS          1238  420.298080   84.241981  1128.542768
# 4   A2ZINFRA          1237   12.991560    3.950000    26.799999
#
#       avg_volume  total_volume  avg_daily_return  volatility  max_daily_gain  \
# 0  245003.299919  3.030691e+08          0.001500    0.032850        0.200000
# 1  978520.287793  1.210430e+09         -0.000698    0.034822        0.199929
# 2   94904.080032  1.173963e+08          0.000192    0.026114        0.199896
# 3  241762.878029  2.993024e+08          0.002204    0.034371        0.199881
# 4  410079.485853  5.072683e+08          0.001223    0.032994        0.192983
#
#    max_daily_loss  annualized_return_pct  annualized_volatility_pct  \
# ...

# %%
(df3.head())
# Out:
#       symbol        date  total_assets  current_assets  cash_and_equivalents  \
# 0  20MICRONS  2026-03-31  7.562226e+09    4.169528e+09           735836000.0
# 1  20MICRONS  2025-09-30  7.417607e+09    3.956573e+09           493685000.0
# 2  20MICRONS  2025-03-31  7.145086e+09    3.751558e+09           312982000.0
# 3  20MICRONS  2024-09-30  6.710909e+09    3.940098e+09            87307000.0
# 4  3IINFOLTD  2026-03-31  6.621700e+09    2.786400e+09           198600000.0
#
#    cash_and_st_investments  short_term_investments  receivables  \
# 0             8.476270e+08            1.117910e+08          NaN
# 1             6.191940e+08            1.255090e+08          NaN
# 2             3.939600e+08            8.097800e+07          NaN
# 3             4.469680e+08            3.596610e+08          NaN
# 4             1.505900e+09            1.307300e+09          NaN
#
#    accounts_receivable  other_receivables     inventory  raw_materials  \
# ...

# %%
(df4.head())
# Out:
#       symbol        date  gross_margin_pct  operating_margin_pct  \
# 0  20MICRONS  2024-09-30               NaN                   NaN
# 1  20MICRONS  2024-12-31               NaN                   NaN
# 2  20MICRONS  2025-03-31             43.28                 10.56
# 3  20MICRONS  2025-06-30             45.44                 10.82
# 4  20MICRONS  2025-09-30             45.23                 11.44
#
#    net_profit_margin_pct  ebitda_margin_pct  roe_pct  roa_pct  roce_pct  \
# 0                    NaN                NaN      NaN      NaN       NaN
# 1                    NaN                NaN      NaN      NaN       NaN
# 2                   6.69              10.49    14.18     8.52     19.27
# 3                   6.82              11.15      NaN      NaN       NaN
# 4                   7.54              12.09    15.29     9.38     21.47
#
#    current_ratio  quick_ratio  cash_ratio  debt_to_equity  debt_to_assets  \
# ...

# %%
(df5.head())
# Out:
#       symbol        date  total_revenue  operating_revenue  cost_of_revenue  \
# 0  20MICRONS  2026-03-31   2.610633e+09       2.610633e+09     1.496189e+09
# 1  20MICRONS  2025-12-31   2.148214e+09       2.148214e+09     1.165871e+09
# 2  20MICRONS  2025-09-30   2.307829e+09       2.307829e+09     1.264090e+09
# 3  20MICRONS  2025-06-30   2.471649e+09       2.471649e+09     1.348469e+09
# 4  20MICRONS  2025-03-31   2.274052e+09       2.274052e+09     1.289926e+09
#
#    gross_profit  operating_expense  selling_general_admin  \
# 0  1.114444e+09        848532000.0                    NaN
# 1  9.823430e+08        754136000.0                    NaN
# 2  1.043739e+09        779816000.0                    NaN
# 3  1.123180e+09        855639000.0                    NaN
# 4  9.841260e+08        743875000.0                    NaN
#
#    research_development  operating_income  interest_expense  interest_income  \
# 0                   NaN       265912000.0        39210000.0              NaN
# ...

# %%
(df6.head())
# Out:
#        symbol        date  operating_cash_flow  cfo_continuing  ni_continuing  \
# 0      AMANTA  2025-03-31          100088000.0             NaN     81502000.0
# 1      AMANTA  2024-12-31           86589000.0             NaN     38943000.0
# 2        ARIS  2025-03-31         -168860000.0             NaN      6600000.0
# 3        ARIS  2024-12-31          -19240000.0             NaN     31450000.0
# 4  BMWVENTLTD  2025-03-31          430399000.0             NaN    136628000.0
#
#    depreciation_amortization  depreciation_depletion  deferred_tax  \
# 0                 46941000.0                     NaN           NaN
# 1                 45053000.0                     NaN           NaN
# 2                  7820000.0                     NaN           NaN
# 3                  7740000.0                     NaN           NaN
# 4                 14300000.0                     NaN           NaN
#
#    deferred_income_tax  stock_based_compensation  change_working_capital  \
# ...

# %%
(df7.head())
# Out:
#       symbol        date       open       high        low      close  \
# 0  20MICRONS  2021-06-24  61.451304  63.417746  61.451304  62.336205
# 1  20MICRONS  2021-06-25  62.926137  63.073621  61.352985  61.451305
# 2  20MICRONS  2021-06-28  61.942919  64.400971  61.942919  62.287045
# 3  20MICRONS  2021-06-29  64.400968  64.597609  58.501643  59.386543
# 4  20MICRONS  2021-06-30  60.074796  60.910536  58.747450  59.140739
#
#    adj_close    volume
# 0  62.336205  122549.0
# 1  61.451305   60252.0
# 2  62.287045  211301.0
# 3  59.386543  398177.0
# 4  59.140739  158219.0

# %%
(df8.head())
# Out:
#       symbol                   company_name              sector  \
# 0  20MICRONS             20 Microns Limited     Basic Materials
# 1  3IINFOLTD            3i Infotech Limited          Technology
# 2     5PAISA         5paisa Capital Limited  Financial Services
# 3    63MOONS  63 moons technologies limited          Technology
# 4   A2ZINFRA  A2Z Infra Engineering Limited         Industrials
#
#                            industry  market_cap_crore  52w_high  52w_low  \
# 0  Other Industrial Metals & Mining            733.68    283.93   129.61
# 1   Information Technology Services            357.56     26.45    12.68
# 2                   Capital Markets           1645.46    432.50   245.50
# 3            Software - Application           3121.13   1130.00   467.00
# 4        Engineering & Construction            246.58     23.25    13.12
#
#    current_price  avg_volume   beta  dividend_yield   pe_ratio  forward_pe  \
# ...

# %%
(df9.head())
# Out:
#       symbol     symbol_ns                   company_name  isin  \
# 0  20MICRONS  20MICRONS.NS             20 Microns Limited   NaN
# 1  3IINFOLTD  3IINFOLTD.NS            3i Infotech Limited   NaN
# 2     5PAISA     5PAISA.NS         5paisa Capital Limited   NaN
# 3    63MOONS    63MOONS.NS  63 moons technologies limited   NaN
# 4   A2ZINFRA   A2ZINFRA.NS  A2Z Infra Engineering Limited   NaN
#
#    market_cap_crore              sector                          industry
# 0            733.68     Basic Materials  Other Industrial Metals & Mining
# 1            357.56          Technology   Information Technology Services
# 2           1645.46  Financial Services                   Capital Markets
# 3           3121.13          Technology            Software - Application
# 4            246.58         Industrials        Engineering & Construction
